# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
pd.set_option('display.expand_frame_repr', False)

# %%
df = pd.read_csv(r"D:\Main tutorials Sunbeam\Class Work\Practice_repo\All csv files\Salary_Data.csv")
print(df)
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.0  140000
# 31             12.0  155000
# ...

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %%
print(df.head())
print()
print(df.tail())
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
#
#     YearsExperience  Salary
# 28             10.3  122391
# 29             10.5  121872
# 30             11.0  140000
# 31             12.0  155000
# 32             13.0  156000

# %%
print(df.describe())
# Out:
#        YearsExperience         Salary
# count        33.000000      33.000000
# mean          5.921212   82760.303030
# std           3.342413   34014.620992
# min           1.100000   37731.000000
# 25%           3.200000   56957.000000
# 50%           5.100000   67938.000000
# 75%           8.700000  109431.000000
# max          13.000000  156000.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  33 non-null     float64
#  1   Salary           33 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 660.0 bytes
# None

# %%
print(f"The first ten records are : \n {df.head(10)}")
print()
print(f"The last ten records are : \n {df.tail(10)}")
# Out:
# The first ten records are :
#     YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891
# 5              2.9   56642
# 6              3.0   60150
# 7              3.2   54445
# 8              3.2   64445
# 9              3.7   57189
#
# The last ten records are :
#      YearsExperience  Salary
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# 30             11.0  140000
# 31             12.0  155000
# 32             13.0  156000

# %%
print(f"The name of all columns are : \n {df.columns}")
# Out:
# The name of all columns are :
#  Index(['YearsExperience', 'Salary'], dtype='object')

# %%
# to check whether their are any null or missing values 
print(f"Tge total missing values count is : \n{df.isna().sum()}")
# Out:
# Tge total missing values count is :
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sns.pairplot(df)
plt.savefig('Mygraph.jpg')

# %%
# Creating a graph using plot function
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Graph of Experience vs Salary")
plt.plot(df)

# %% [markdown]
# ### Preprocessing

# %%
# Adding new column to the dataset
df['Dummy Column'] = 100
df['Bonus'] = df['Salary'] + (df['Salary'] * 0.10)
df['Total Salary'] = df['Bonus'] + df['Salary']
print(df.head())
# Out:
#    YearsExperience  Salary  Dummy Column    Bonus  Total Salary
# 0              1.1   39343           100  43277.3       82620.3
# 1              1.3   46205           100  50825.5       97030.5
# 2              1.5   37731           100  41504.1       79235.1
# 3              2.0   43525           100  47877.5       91402.5
# 4              2.2   39891           100  43880.1       83771.1

# %% [markdown]
# ### Reading csv file or finding the correlation between the columns

# %%
df1 = pd.read_csv(r"D:\Main tutorials Sunbeam\Class Work\Practice_repo\All csv files\Salary_Data.csv")
corr = df1.corr()
print(corr)
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.983642
# Salary                  0.983642  1.000000

# %%
corr.style.background_gradient(cmap='berlin')
# Out:
# <style type="text/css">
# #T_d90c1_row0_col0, #T_d90c1_row1_col1 {
#   background-color: #ffadad;
#   color: #000000;
# }
# #T_d90c1_row0_col1, #T_d90c1_row1_col0 {
#   background-color: #9eb0ff;
#   color: #000000;
# }
# </style>
# <table id="T_d90c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d90c1_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_d90c1_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d90c1_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_d90c1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d90c1_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_d90c1_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_d90c1_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %%
corr.style.background_gradient(cmap='Spectral')
# Out:
# <style type="text/css">
# #T_34aa1_row0_col0, #T_34aa1_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_34aa1_row0_col1, #T_34aa1_row1_col0 {
#   background-color: #9e0142;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_34aa1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34aa1_level0_col0" class="col_heading level0 col0" >YearsExperience</th>
#       <th id="T_34aa1_level0_col1" class="col_heading level0 col1" >Salary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34aa1_level0_row0" class="row_heading level0 row0" >YearsExperience</th>
#       <td id="T_34aa1_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_34aa1_row0_col1" class="data row0 col1" >0.983642</td>
#     </tr>
#     <tr>
#       <th id="T_34aa1_level0_row1" class="row_heading level0 row1" >Salary</th>
#       <td id="T_34aa1_row1_col0" class="data row1 col0" >0.983642</td>
# ...

# %% [markdown]
# ### categorical to numeric value ,replace values of categorical data to numeric data
# #### find the correlation among the feature

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df2 = pd.read_csv('50_Startups.csv')
df2.head()
# Out:
#          RnD  Administration  Marketing       State     Profit
# 0  165349.20       136897.80  471784.10    New York  192261.83
# 1  162597.70       151377.59  443898.53  California  191792.06
# 2  153441.51       101145.55  407934.54     Florida  191050.39
# 3  144372.41       118671.85  383199.62    New York  182901.99
# 4  142107.34        91391.77  366168.42     Florida  166187.94

# %%
print(df2.describe())
print()
print("The information of the datasert is : \n")
print(df2.info())
# Out:
#                  RnD  Administration      Marketing         Profit
# count      50.000000       50.000000      50.000000      50.000000
# mean    73721.615600   121344.639600  211025.097800  112012.639200
# std     45902.256482    28017.802755  122290.310726   40306.180338
# min         0.000000    51283.140000       0.000000   14681.400000
# 25%     39936.370000   103730.875000  129300.132500   90138.902500
# 50%     73051.080000   122699.795000  212716.240000  107978.190000
# 75%    101602.800000   144842.180000  299469.085000  139765.977500
# max    165349.200000   182645.560000  471784.100000  192261.830000
#
# The information of the datasert is :
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RnD             50 non-null     float64
#  1   Administration  50 non-null     float64
# ...

# %%
# counting the missing values
print(df2.isna().sum())
# Out:
# RnD               0
# Administration    0
# Marketing         0
# State             0
# Profit            0
# dtype: int64

# %% [markdown]
# ### Converting the categorical data into the numrical data
# #### first step is to find the unique states
# #### assigning the the numbers to the unique states

# %%
unique_states = df2['State'].unique()
print(f"The unique states in the column are : {unique_states}")
# Out:
# The unique states in the column are : ['New York' 'California' 'Florida']

# %%
# replacing the unique states with the unique number
unique_states_number = [1 , 2 , 3]
df2.replace(unique_states , unique_states_number , inplace=True)
df2.head()
# Out:
# C:\Users\Atharv Patil\AppData\Local\Temp\ipykernel_12952\1388192854.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2.replace(unique_states , unique_states_number , inplace=True)
#          RnD  Administration  Marketing  State     Profit
# 0  165349.20       136897.80  471784.10      1  192261.83
# 1  162597.70       151377.59  443898.53      2  191792.06
# 2  153441.51       101145.55  407934.54      3  191050.39
# 3  144372.41       118671.85  383199.62      1  182901.99
# 4  142107.34        91391.77  366168.42      3  166187.94

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RnD             50 non-null     float64
#  1   Administration  50 non-null     float64
#  2   Marketing       50 non-null     float64
#  3   State           50 non-null     int64
#  4   Profit          50 non-null     float64
# dtypes: float64(4), int64(1)
# memory usage: 2.1 KB

# %%
print(df2.corr())
# Out:
#                      RnD  Administration  Marketing     State    Profit
# RnD             1.000000        0.241955   0.724248  0.037930  0.972900
# Administration  0.241955        1.000000  -0.032154  0.003026  0.200717
# Marketing       0.724248       -0.032154   1.000000  0.137777  0.747766
# State           0.037930        0.003026   0.137777  1.000000  0.048471
# Profit          0.972900        0.200717   0.747766  0.048471  1.000000

# %%
print(f"The correlation between Profit and Rnd is : {df2['Profit'].corr(df2['RnD'])}")
print(f"The correlation between Profit and Marketing is : {df2['Profit'].corr(df2['Marketing'])}")
print(f"The correlation between Profit and Administration is : {df2['Profit'].corr(df2['Administration'])}")
# Out:
# The correlation between Profit and Rnd is : 0.9729004656594832
# The correlation between Profit and Marketing is : 0.7477657217414766
# The correlation between Profit and Administration is : 0.20071656826872125

# %%
sns.pairplot(df2)

# %%
df2.drop('State' , axis = 1 , inplace = True) # this drops the state column because by looking at the correlation and the pairplot we understand that these are irrelevant columns as their correlation is very low
# same goes for the administration column.
df2.drop('Administration' , axis = 1 , inplace = True)

# %%
# to delete the columns from the dataset
df3 = pd.read_csv(r"D:\Main tutorials Sunbeam\Class Work\Practice_repo\All csv files\titanic.csv")
print(df3.head())
# Out:
#    pclass  survived                                             name     sex      age  sibsp  parch  ticket      fare    cabin embarked boat   body                        home.dest
# 0       1         1                    Allen, Miss. Elisabeth Walton  female  29.0000      0      0   24160  211.3375       B5        S    2    NaN                     St Louis, MO
# 1       1         1                   Allison, Master. Hudson Trevor    male   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0                     Allison, Miss. Helen Loraine  female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# ...

# %%
# steps to delete the columns 
print(f"The total columns in the dataset are : {df3.columns}")
# Out:
# The total columns in the dataset are : Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# to remove single column
del df3['home.dest']
print(df3.head())
# Out:
#    pclass  survived                                             name     sex      age  sibsp  parch  ticket      fare    cabin embarked boat   body
# 0       1         1                    Allen, Miss. Elisabeth Walton  female  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1       1         1                   Allison, Master. Hudson Trevor    male   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2       1         0                     Allison, Miss. Helen Loraine  female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN

# %%
# to remove miltiple columns 
df3.drop(['body' , 'boat' , 'embarked'] , axis = 1 , inplace = True)
print(df3.head())
# Out:
#    pclass  survived                                             name     sex      age  sibsp  parch  ticket      fare    cabin
# 0       1         1                    Allen, Miss. Elisabeth Walton  female  29.0000      0      0   24160  211.3375       B5
# 1       1         1                   Allison, Master. Hudson Trevor    male   0.9167      1      2  113781  151.5500  C22 C26
# 2       1         0                     Allison, Miss. Helen Loraine  female   2.0000      1      2  113781  151.5500  C22 C26
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1      2  113781  151.5500  C22 C26
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000      1      2  113781  151.5500  C22 C26

# %% [markdown]
# ## Handling the missing values and NanN values

# %%
df4 = pd.read_csv(r"D:\Main tutorials Sunbeam\Class Work\Practice_repo\All csv files\titanic.csv")
print(df4.head())
# Out:
#    pclass  survived                                             name     sex      age  sibsp  parch  ticket      fare    cabin embarked boat   body                        home.dest
# 0       1         1                    Allen, Miss. Elisabeth Walton  female  29.0000      0      0   24160  211.3375       B5        S    2    NaN                     St Louis, MO
# 1       1         1                   Allison, Master. Hudson Trevor    male   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN  Montreal, PQ / Chesterville, ON
# 2       1         0                     Allison, Miss. Helen Loraine  female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN  Montreal, PQ / Chesterville, ON
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0  Montreal, PQ / Chesterville, ON
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df4.describe()
# Out:
#             pclass     survived          age        sibsp        parch         fare        body
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000  121.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027    33.295479  160.809917
# std       0.837836     0.486055    14.413500     1.041658     0.865560    51.758668   97.696922
# min       1.000000     0.000000     0.166700     0.000000     0.000000     0.000000    1.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000     7.895800   72.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000    14.454200  155.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000    31.275000  256.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000   512.329200  328.000000

# %%
df4.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
df4.dropna(axis=0,  inplace=True)

# %%
df4.head()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df4.dropna(axis = 1, inplace=True)

# %%
df4.head()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df4['age'].fillna(df4['age'].mean() , inplace=True) # here the age column is taken as example for solving this problem

# %%
df4.head()
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
df4['cabin'].fillna(df4['cabin'].mean(), inplace=True) # cabin is also taken same as age

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     0 non-null      int64
#  1   survived   0 non-null      int64
#  2   name       0 non-null      object
#  3   sex        0 non-null      object
#  4   age        0 non-null      float64
#  5   sibsp      0 non-null      int64
#  6   parch      0 non-null      int64
#  7   ticket     0 non-null      object
#  8   fare       0 non-null      float64
#  9   cabin      0 non-null      object
#  10  embarked   0 non-null      object
#  11  boat       0 non-null      object
#  12  body       0 non-null      float64
#  13  home.dest  0 non-null      object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 0.0+ bytes

# %%
df4.isna().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %% [markdown]
# ### Program 3 in sunbeam class work folder that is df2 in my file work continued

# %%
sns.heatmap(df2.corr())
# Out:
# <Axes: >

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   RnD        50 non-null     float64
#  1   Marketing  50 non-null     float64
#  2   Profit     50 non-null     float64
# dtypes: float64(3)
# memory usage: 1.3 KB
# None

# %% [markdown]
# #### Spliting the data

# %%
x = df2.drop('Profit' , axis= 1) # Here this variable is used for training the model so only input variables are kept and output vars are removed 

y = df2['Profit'] # here this is prediction var so only output column is stored

# %% [markdown]
# ### Model Building

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(x , y) # the fit function is used to insert the x and y vars into the linear regression model
# Out:
# LinearRegression()

# %%
model.score(x , y)
# Out:
# 0.9504503015559763
